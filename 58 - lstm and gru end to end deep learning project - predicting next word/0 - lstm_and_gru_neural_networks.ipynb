# %% [markdown]
# ## LSTM and GRU RNN Gates
# <table>
# <tr>
#     <td>GRU RNN Gates</td>
#     <td>LSTM RNN Gates</td>
# </tr>
# <tr>
#     <td>
#         1) Reset Gate
#         <br/>2) Update Gate
#     </td>
#     <td>
#         1) Forget Gate
#         2) Input Gate and Candidate Memory
#         3) Output Gate
#     </td>
# </tr>
# </table>
