# %% [markdown]
# ### Parts of Speech (POS) Tagging
# <table border="1" cellpadding="6" cellspacing="0">
#   <thead>
#     <tr>
#       <th>Category</th>
#       <th>Tag</th>
#       <th>Description</th>
#       <th>Example</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td>Nouns</td><td>NN</td><td>Noun, singular or mass</td><td>dog, car</td></tr>
#     <tr><td>Nouns</td><td>NNS</td><td>Noun, plural</td><td>dogs</td></tr>
#     <tr><td>Nouns</td><td>NNP</td><td>Proper noun, singular</td><td>John</td></tr>
#     <tr><td>Nouns</td><td>NNPS</td><td>Proper noun, plural</td><td>Americans</td></tr>
#     <tr><td>Verbs</td><td>VB</td><td>Verb, base form</td><td>run</td></tr>
#     <tr><td>Verbs</td><td>VBD</td><td>Verb, past tense</td><td>ran</td></tr>
#     <tr><td>Verbs</td><td>VBG</td><td>Verb, gerund or present participle</td><td>running</td></tr>
#     <tr><td>Verbs</td><td>VBN</td><td>Verb, past participle</td><td>eaten</td></tr>
#     <tr><td>Verbs</td><td>VBP</td><td>Verb, non-3rd person singular present</td><td>run</td></tr>
#     <tr><td>Verbs</td><td>VBZ</td><td>Verb, 3rd person singular present</td><td>runs</td></tr>
#     <tr><td>Adjectives</td><td>JJ</td><td>Adjective</td><td>big</td></tr>
#     <tr><td>Adjectives</td><td>JJR</td><td>Adjective, comparative</td><td>bigger</td></tr>
#     <tr><td>Adjectives</td><td>JJS</td><td>Adjective, superlative</td><td>biggest</td></tr>
#     <tr><td>Adverbs</td><td>RB</td><td>Adverb</td><td>quickly</td></tr>
#     <tr><td>Adverbs</td><td>RBR</td><td>Adverb, comparative</td><td>faster</td></tr>
#     <tr><td>Adverbs</td><td>RBS</td><td>Adverb, superlative</td><td>fastest</td></tr>
#     <tr><td>Adverbs</td><td>WRB</td><td>Wh-adverb</td><td>where, when</td></tr>
#     <tr><td>Pronouns</td><td>PRP</td><td>Personal pronoun</td><td>I, you, he</td></tr>
#     <tr><td>Pronouns</td><td>PRP$</td><td>Possessive pronoun</td><td>my, your</td></tr>
#     <tr><td>Pronouns</td><td>WP</td><td>Wh-pronoun</td><td>who, what</td></tr>
#     <tr><td>Pronouns</td><td>WP$</td><td>Possessive wh-pronoun</td><td>whose</td></tr>
#     <tr><td>Determiners</td><td>DT</td><td>Determiner</td><td>the, a</td></tr>
#     <tr><td>Determiners</td><td>PDT</td><td>Predeterminer</td><td>all, both</td></tr>
#     <tr><td>Determiners</td><td>WDT</td><td>Wh-determiner</td><td>which</td></tr>
#     <tr><td>Prepositions &amp; Conjunctions</td><td>IN</td><td>Preposition or subordinating conjunction</td><td>in, of, because</td></tr>
#     <tr><td>Prepositions &amp; Conjunctions</td><td>CC</td><td>Coordinating conjunction</td><td>and, or, but</td></tr>
#     <tr><td>Numbers</td><td>CD</td><td>Cardinal number</td><td>one, 2</td></tr>
#     <tr><td>Particles &amp; Others</td><td>RP</td><td>Particle</td><td>up (pick up)</td></tr>
#     <tr><td>Particles &amp; Others</td><td>TO</td><td>to</td><td>to</td></tr>
#     <tr><td>Particles &amp; Others</td><td>UH</td><td>Interjection</td><td>oh, wow</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>SYM</td><td>Symbol</td><td>$, %, +</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>FW</td><td>Foreign word</td><td>bonjour</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>LS</td><td>List item marker</td><td>1), A)</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>EX</td><td>Existential “there”</td><td>there</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>POS</td><td>Possessive ending</td><td>&rsquo;s</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>MD</td><td>Modal verb</td><td>can, should</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>``</td><td>Opening quotation mark</td><td>&ldquo;</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>''</td><td>Closing quotation mark</td><td>&rdquo;</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>.</td><td>Sentence-final punctuation</td><td>. ? !</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>,</td><td>Comma</td><td>,</td></tr>
#     <tr><td>Symbols &amp; Special Tokens</td><td>:</td><td>Colon or ellipsis</td><td></td></tr>
#   </tbody>
# </table>
#
#
# ### In this document:-
# - A) Example #1 - Find the Parts of Speech (POS) Tags for the Corpus
# - B) Example #2 - Find the Parts of Speech (POS) Tags for the Corpus
#
#
# ### Process of POS Tagging
# - 1) Break the Corpus into Documents / Sentences
# - 2) Break the Documents / Sentences into Words
# - 3) For each Word find the POS tag.

# %%
corpus = """
I have three visions for India. In three thousand years of our history, people from all over the world have come and invaded us, captured our lands, conquered our minds, and taken away our wealth. Yet, we have not done this to any other nation. Why? Because we respected the freedom of others. That is why my first vision is that India must stand up to the world. No one should underestimate us. We should be strong not only as a military power but also as an economic power. Both must go hand in hand.
My second vision for India is development. For fifty years we have been a developing nation. It is time we see ourselves as a developed nation. We are among the top five nations of the world in terms of GDP, but we are still a developing nation. Why? We are still not free from poverty, illiteracy, and unemployment. A developed India means a nation where people are empowered, where education and health are accessible to all, where science and technology drive growth, and where self-reliance is a way of life.
My third vision for India is that India must stand up to the world. Because only strength respects strength. We must be strong enough to protect our sovereignty and confident enough to contribute to global peace and prosperity. Strength does not mean aggression; it means confidence, preparedness, and self-belief. A strong nation is one that respects others and is respected in return.
To achieve these visions, you—the young people of India—are the most important resource. If you want to shine like the sun, first burn like the sun. Dreams are not what you see in sleep; dreams are things which do not let you sleep. Dream, dream, dream. Dreams transform into thoughts, and thoughts result in action. Excellence is a continuous process, not an accident. You must have the courage to think differently, to invent, to travel the unexplored path, and to succeed.
If a country is to be corruption-free and become a nation of beautiful minds, I strongly feel there are three key societal members who can make a difference: the father, the mother, and the teacher. Parents must nurture values, teachers must ignite curiosity, and students must carry the nation forward with integrity and hard work. We should not give up, and we should not allow problems to defeat us. Confidence and hard work are the best weapons.
Let us together build an India that is strong, developed, and respected—a nation that future generations will be proud of.
"""

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/ankur/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
#A) Example #1 - Find the Parts of Speech (POS) Tags for the Corpus

#1) Break the Corpus into Documents / Sentences
#2) Break the Documents / Sentences into Words
#3) For each Word find the POS tag.

# Break the Corpus into Documents / Sentences
porter_stemmer = PorterStemmer()
documents = nltk.sent_tokenize(corpus)

for i in range(len(documents)):
    words = nltk.word_tokenize(documents[i]) # Break each Document into Words
    words = [word for word in words if word not in set(stopwords.words('english'))]
    pos_tag = nltk.pos_tag(words) # Find the POS Tag for all the 'words' in the 'document/sentence'
    print('pos = ',pos_tag)
# Out:
# pos =  [('I', 'PRP'), ('three', 'CD'), ('visions', 'NNS'), ('India', 'NNP'), ('.', '.')]
# pos =  [('In', 'IN'), ('three', 'CD'), ('thousand', 'CD'), ('years', 'NNS'), ('history', 'NN'), (',', ','), ('people', 'NNS'), ('world', 'NN'), ('come', 'VBP'), ('invaded', 'VBN'), ('us', 'PRP'), (',', ','), ('captured', 'VBD'), ('lands', 'NNS'), (',', ','), ('conquered', 'VBD'), ('minds', 'NNS'), (',', ','), ('taken', 'VBN'), ('away', 'RP'), ('wealth', 'NN'), ('.', '.')]
# pos =  [('Yet', 'RB'), (',', ','), ('done', 'VBN'), ('nation', 'NN'), ('.', '.')]
# pos =  [('Why', 'WRB'), ('?', '.')]
# pos =  [('Because', 'IN'), ('respected', 'VBN'), ('freedom', 'NN'), ('others', 'NNS'), ('.', '.')]
# pos =  [('That', 'DT'), ('first', 'JJ'), ('vision', 'NN'), ('India', 'NNP'), ('must', 'MD'), ('stand', 'VB'), ('world', 'NN'), ('.', '.')]
# pos =  [('No', 'DT'), ('one', 'NN'), ('underestimate', 'NN'), ('us', 'PRP'), ('.', '.')]
# ...

# %%
#B) Example #2 - Find the Parts of Speech (POS) Tags for the Corpus 
pos_tags = nltk.pos_tag("Taj Mahal is a beautiful Monument".split())
print('pos_tags = ',pos_tags)
# Out:
# pos_tags =  [('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('Monument', 'NN')]
