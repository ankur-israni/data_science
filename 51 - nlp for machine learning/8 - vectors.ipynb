# %% [markdown]
# ### Vectors
#     - Vectors are the numerical representation of a specific text
#
# ### Ways to convert text into Vectors
# - 1) One Hot Encoding
# - 2) Bag of Words (BOW)
# - 3) TF-IDF
# - 4) Word2Vec
# - 5) AvgWord2Vec
