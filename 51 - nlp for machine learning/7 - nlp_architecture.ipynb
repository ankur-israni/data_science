# %% [markdown]
# ### Sentiment Analysis
# Following is the generic architecture followed when doing Natural Language Processing (NLP)

# %%
from IPython.display import Image
Image(filename='resources/images/nlp_architecture.png',height=500,width=600)
